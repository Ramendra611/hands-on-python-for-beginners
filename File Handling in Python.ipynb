# %% [markdown]
# In Python, files can contain:
# - **Text data** (e.g., `.txt`, `.csv`)
# - **Binary data** (e.g., images, audio)

# %%
    -  Using open()
    -  Using a context manager with

# %%
pwd
# Out:
# '/Users/ram/Documents/codeverra/PythonMastery'

# %% [markdown]
# ## Writing something to a file

# %%
name = "Ramesh"

file = open("sample.txt", "w" )
file.write(name)
# Out:
# 6

# %%
name = "Suresh"

file = open("sample.txt", "w" )
file.write(name)
# Out:
# 6

# %%
message = "hello how are you?"

file = open("message.txt", "w")
file.write(message)
file.close()

# %%
message = "\nI am fine. Thank you!"

file = open("message.txt", "a")  # a --> append
file.write(message)
file.close()

# %%
message = "Where are you coming from??\n"

file = open("message.txt", "a")  # a --> append
file.write(message)
file.close()

# %%
message = "I am coming from Delhi/n"

file = open("message.txt", "a")  # a --> append
file.write(message)
file.close()

# %%
message = "I am coming from Delhi/n"

file = open("message1", "w")  # a --> append
file.write(message)
file.close()

# %% [markdown]
# ## Reading the contents of a file

# %%
file = open("message.txt", "r")
info = file.read()
file.close()


print(info)
# Out:
# hello how are you?I am fine. Thank you!
# I am fine. Thank you!Where are you coming from??I am coming from Delhi/

# %% [markdown]
# ### **Common Modes:**
# | Mode   | Description                                         |
# | ------ | --------------------------------------------------- |
# | `'r'`  | Read mode (default)                                 |
# | `'w'`  | Write mode (creates a new file if it doesn’t exist) |
# | `'a'`  | Append mode (adds content at the end)               |
# | `'r+'` | Read and write mode                                 |
# | `'b'`  | Binary mode (used for non-text files like images)   |

# %%
file = open("awesomepython.txt", "r")
info = file.read()
file.close()

info
# Out:
# "\ufeffWhy Python is Awesome\n1. Easy as Pie: Python’s syntax is so simple, it feels like having a conversation with your code. No more head-scratching!\n2. One Language, Many Hats: From building websites to crunching data, Python can do it all — it’s like the Swiss Army knife of programming.\n3. Quick Learner's Best Friend: Whether you're a newbie or a seasoned pro, Python welcomes everyone with open arms.\n4. Libraries Galore!: Need a tool? Python’s got a library for it — data science, AI, web development, automation… you name it!\n5. Community Love: With a huge and friendly community, Python developers are like your neighborhood superheroes — always there to help!\n6. Runs Anywhere: Windows, Mac, Linux — Python doesn’t care. It runs happily on any system, no complaints!\n7. Fast Prototypes, Faster Ideas: Got a wild idea? Test it with Python in minutes — no waiting around!\n8. Automate All the Boring Stuff: Why do manual work when Python can do it for you? Automate and chill.\n9. C
# ...

# %%
print(info)
# Out:
# ﻿Why Python is Awesome
# 1. Easy as Pie: Python’s syntax is so simple, it feels like having a conversation with your code. No more head-scratching!
# 2. One Language, Many Hats: From building websites to crunching data, Python can do it all — it’s like the Swiss Army knife of programming.
# 3. Quick Learner's Best Friend: Whether you're a newbie or a seasoned pro, Python welcomes everyone with open arms.
# 4. Libraries Galore!: Need a tool? Python’s got a library for it — data science, AI, web development, automation… you name it!
# 5. Community Love: With a huge and friendly community, Python developers are like your neighborhood superheroes — always there to help!
# 6. Runs Anywhere: Windows, Mac, Linux — Python doesn’t care. It runs happily on any system, no complaints!
# 7. Fast Prototypes, Faster Ideas: Got a wild idea? Test it with Python in minutes — no waiting around!
# 8. Automate All the Boring Stuff: Why do manual work when Python can do it for you? Automate and chill.
# ...

# %%
print(dir(file))
# Out:
# ['_CHUNK_SIZE', '__class__', '__del__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_checkClosed', '_checkReadable', '_checkSeekable', '_checkWritable', '_finalizing', 'buffer', 'close', 'closed', 'detach', 'encoding', 'errors', 'fileno', 'flush', 'isatty', 'line_buffering', 'mode', 'name', 'newlines', 'read', 'readable', 'readline', 'readlines', 'reconfigure', 'seek', 'seekable', 'tell', 'truncate', 'writable', 'write', 'write_through', 'writelines']

# %% [markdown]
# 'buffer', 'close', 'closed', 'detach', 'encoding', 'errors', 'fileno', 'flush', 'isatty', 'line_buffering', 'mode', 'name', 'newlines', 'read', 'readable', 'readline', 'readlines', 'reconfigure', 'seek', 'seekable', 'tell', 'truncate', 'writable', 'write', 'write_through', 'writelines'

# %%
file = open("awesomepython.txt", "r")
info = file.readlines()
file.close()

info
# Out:
# ['\ufeffWhy Python is Awesome\n',
#  '1. Easy as Pie: Python’s syntax is so simple, it feels like having a conversation with your code. No more head-scratching!\n',
#  '2. One Language, Many Hats: From building websites to crunching data, Python can do it all — it’s like the Swiss Army knife of programming.\n',
#  "3. Quick Learner's Best Friend: Whether you're a newbie or a seasoned pro, Python welcomes everyone with open arms.\n",
#  '4. Libraries Galore!: Need a tool? Python’s got a library for it — data science, AI, web development, automation… you name it!\n',
#  '5. Community Love: With a huge and friendly community, Python developers are like your neighborhood superheroes — always there to help!\n',
#  '6. Runs Anywhere: Windows, Mac, Linux — Python doesn’t care. It runs happily on any system, no complaints!\n',
#  '7. Fast Prototypes, Faster Ideas: Got a wild idea? Test it with Python in minutes — no waiting around!\n',
# ...

# %%
info[3]
# Out:
# "3. Quick Learner's Best Friend: Whether you're a newbie or a seasoned pro, Python welcomes everyone with open arms.\n"

# %%
file = open("awesomepython.txt", "r")

# %%
file.readlines()
# Out:
# ['4. Libraries Galore!: Need a tool? Python’s got a library for it — data science, AI, web development, automation… you name it!\n',
#  '5. Community Love: With a huge and friendly community, Python developers are like your neighborhood superheroes — always there to help!\n',
#  '6. Runs Anywhere: Windows, Mac, Linux — Python doesn’t care. It runs happily on any system, no complaints!\n',
#  '7. Fast Prototypes, Faster Ideas: Got a wild idea? Test it with Python in minutes — no waiting around!\n',
#  '8. Automate All the Boring Stuff: Why do manual work when Python can do it for you? Automate and chill.\n',
#  '9. Career Booster: Python isn’t just fun; it’s also in high demand. Great skill = better jobs and fat paychecks!\n',
#  '10. Trusted by Giants: If Google, Netflix, and NASA trust Python, why shouldn’t you? 🚀\n',
#  '\n']

# %%
file.readline()
# Out:
# "3. Quick Learner's Best Friend: Whether you're a newbie or a seasoned pro, Python welcomes everyone with open arms.\n"

# %%
file = open("awesomepython.txt", "r")

# %%
file.read()
# Out:
# "Why Python is Awesome\n1. Easy as Pie: Python’s syntax is so simple, it feels like having a conversation with your code. No more head-scratching!\n2. One Language, Many Hats: From building websites to crunching data, Python can do it all — it’s like the Swiss Army knife of programming.\n3. Quick Learner's Best Friend: Whether you're a newbie or a seasoned pro, Python welcomes everyone with open arms.\n4. Libraries Galore!: Need a tool? Python’s got a library for it — data science, AI, web development, automation… you name it!\n5. Community Love: With a huge and friendly community, Python developers are like your neighborhood superheroes — always there to help!\n6. Runs Anywhere: Windows, Mac, Linux — Python doesn’t care. It runs happily on any system, no complaints!\n7. Fast Prototypes, Faster Ideas: Got a wild idea? Test it with Python in minutes — no waiting around!\n8. Automate All the Boring Stuff: Why do manual work when Python can do it for you? Automate and chill.\n9. Career 
# ...

# %%
info = file.read(10)

print("Current position of pointer:  " ,file.tell())

print(info)
# Out:
# Current position of pointer:   30
# e
# 1. Easy

# %%
file = open("awesomepython.txt", "r")

# %%
file.read(15)
# Out:
# 'Why Python is A'

# %%
file.tell()
# Out:
# 15

# %%
file.seek(25)
# Out:
# 25

# %%
file.tell()
# Out:
# 25

# %%
file.read(15)
# Out:
# 'Easy as Pie: Py'

# %%
file = open("awesomepython.txt", "r")
print(file.read(10))
file.seek(0)
# Out:
# Why Python
# 0

# %%
list_of_info = ["hello\n", "how are you?\n", "i am good\n"]

# file = open("new_file", "w")
# file.write()

open("new_file", "w").writelines(list_of_info)

# %%
'buffer', 'close', 'closed', 'detach', 'encoding', 'errors', 'fileno', 'flush', 'isatty', 'line_buffering', 'mode', 'name', 'newlines', 'read', 'readable', 'readline', 'readlines', 'reconfigure', 'seek', 'seekable', 'tell', 'truncate', 'writable', 'write', 'write_through', 'writelines'
# Out:
# ('buffer',
#  'close',
#  'closed',
#  'detach',
#  'encoding',
#  'errors',
#  'fileno',
#  'flush',
#  'isatty',
#  'line_buffering',
#  'mode',
#  'name',
#  'newlines',
#  'read',
#  'readable',
#  'readline',
#  'readlines',
#  'reconfigure',
#  'seek',
#  'seekable',
#  'tell',
#  'truncate',
#  'writable',
#  'write',
#  'write_through',
#  'writelines')

# %%
file = open("awesomepython.txt", "r")

# %%
file.seekable()
# Out:
# True

# %%
file.name
# Out:
# 'awesomepython.txt'

# %%
file = open("awesomepython.txt", "r")

# %%
file.close()

# %%
file.closed
# Out:
# True

# %% [markdown]
# ## using context manager

# %%
file = open("awesomepython.txt", "r")

# %%
with open("awesomepython.txt", "r") as file:
    info = file.read()
print(info)
# Out:
# ﻿Why Python is Awesome
# 1. Easy as Pie: Python’s syntax is so simple, it feels like having a conversation with your code. No more head-scratching!
# 2. One Language, Many Hats: From building websites to crunching data, Python can do it all — it’s like the Swiss Army knife of programming.
# 3. Quick Learner's Best Friend: Whether you're a newbie or a seasoned pro, Python welcomes everyone with open arms.
# 4. Libraries Galore!: Need a tool? Python’s got a library for it — data science, AI, web development, automation… you name it!
# 5. Community Love: With a huge and friendly community, Python developers are like your neighborhood superheroes — always there to help!
# 6. Runs Anywhere: Windows, Mac, Linux — Python doesn’t care. It runs happily on any system, no complaints!
# 7. Fast Prototypes, Faster Ideas: Got a wild idea? Test it with Python in minutes — no waiting around!
# 8. Automate All the Boring Stuff: Why do manual work when Python can do it for you? Automate and chill.
# ...

# %%
file.closed
# Out:
# True

# %%
with open("awesomepython.txt", "a") as file:
    file.write("11. It is very useful for doing data science related work. ")
# print(info)
# Out:
# ﻿Why Python is Awesome
# 1. Easy as Pie: Python’s syntax is so simple, it feels like having a conversation with your code. No more head-scratching!
# 2. One Language, Many Hats: From building websites to crunching data, Python can do it all — it’s like the Swiss Army knife of programming.
# 3. Quick Learner's Best Friend: Whether you're a newbie or a seasoned pro, Python welcomes everyone with open arms.
# 4. Libraries Galore!: Need a tool? Python’s got a library for it — data science, AI, web development, automation… you name it!
# 5. Community Love: With a huge and friendly community, Python developers are like your neighborhood superheroes — always there to help!
# 6. Runs Anywhere: Windows, Mac, Linux — Python doesn’t care. It runs happily on any system, no complaints!
# 7. Fast Prototypes, Faster Ideas: Got a wild idea? Test it with Python in minutes — no waiting around!
# 8. Automate All the Boring Stuff: Why do manual work when Python can do it for you? Automate and chill.
# ...

# %%
lines_to_be_added = ["great and easy to learn\n", "it is fun to do projects in python"]

# %%
with open("awesomepython.txt", "a") as file:
    file.writelines(lines_to_be_added)

# %%
list_of_names = ["Ram", "Shyam", "Radheshyam"]

# %%
with open("name_list", "w") as file:
    file.write(list_of_names)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[127], line 2
#       1 with open("name_list", "w") as file:
# ----> 2     file.write(list_of_names)
#
# TypeError: write() argument must be str, not list

# %%
with open("name_list", "w") as file:
    file.writelines(list_of_names)

# %%
with open("name_list", "r") as file:
    data = file.read()

# %%
data
# Out:
# 'RamShyamRadheshyam'

# %% [markdown]
# ## Serialisation and Deserialisation
#     - Json
#     - Pickle
#     - joblib

# %%
import json

# %%
list_of_names = ["Ram", "Shyam", "Radheshyam"]

my_dictionary = {
    
    "name":"Ram",
    "city":"Delhi"
}

# %%
with open("list.json", "w") as file:
    json.dump(list_of_names, file)

# %%
with open("list.json", "r") as file:
    data = json.load(file)
data
# Out:
# ['Ram', 'Shyam', 'Radheshyam']

# %%
type(data)
# Out:
# list

# %%
with open("dictionary.json", "w") as file:
    json.dump(my_dictionary, file)

# %%
with open("dictionary.json", "r") as file:
    data = json.load(file)

# %%
data
# Out:
# {'name': 'Ram', 'city': 'Delhi'}

# %%
my_tuple = (5, 6, 7, 8)
with open("tuple.json", "w") as file:
    json.dump(my_tuple, file)

# %%
with open("tuple.json", "r") as file:
    data = json.load(file)

# %%
data =tuple(data)

# %%
data
# Out:
# (5, 6, 7, 8)

# %% [markdown]
# ## json <--> string

# %%
my_dictionary = {
    
    "name":"Ram",
    "city":"Delhi"
}

# %%
str(my_dictionary)
# Out:
# "{'name': 'Ram', 'city': 'Delhi'}"

# %%
json.dumps(my_dictionary)  # ---> jsonifialble string
# Out:
# '{"name": "Ram", "city": "Delhi"}'

# %%
json.loads('{"name": "Ram", "city": "Delhi"}')
# Out:
# {'name': 'Ram', 'city': 'Delhi'}

# %% [markdown]
# ## pickle

# %%
list_of_names = ["Ram", "Shyam", "Radheshyam"]

my_dictionary = {
    
    "name":"Ram",
    "city":"Delhi"
}


my_tuple = (5, 6, 7, 8)

# %%
import pickle

# %%
with open("dictionary.pkl", "wb") as file:
    pickle.dump(list_of_names, file)

# %%
with open("dictionary.pkl" , "rb") as file:
    data = pickle.load(file)

# %%
data
# Out:
# ['Ram', 'Shyam', 'Radheshyam']

# %%
with open("tuple.pkl", "wb") as file:
    pickle.dump(my_tuple, file)

# %%
with open("tuple.pkl" , "rb") as file:
    data = pickle.load(file)

# %%
data
# Out:
# (5, 6, 7, 8)

# %%
def print_multiplication_table(number):
    for i in range(1, 10):
        print(f"{number} X {i} = {number * i} ")

# %%
print_multiplication_table(5)
# Out:
# 5 X 1 = 5
# 5 X 2 = 10
# 5 X 3 = 15
# 5 X 4 = 20
# 5 X 5 = 25
# 5 X 6 = 30
# 5 X 7 = 35
# 5 X 8 = 40
# 5 X 9 = 45

# %%
with open("multiplication_function.pkl", "wb") as file:
    pickle.dump(print_multiplication_table, file)

# %%
with open("multiplication_function.pkl", "rb") as file:
    fn = pickle.load(file)

# %%
fn(9)
# Out:
# 9 X 1 = 9
# 9 X 2 = 18
# 9 X 3 = 27
# 9 X 4 = 36
# 9 X 5 = 45
# 9 X 6 = 54
# 9 X 7 = 63
# 9 X 8 = 72
# 9 X 9 = 81

# %% [markdown]
# ### read images in python

# %%
with open("rohit and virat.jpg", "rb") as file:
    data  = file.read()

# %%
# data

# %%
type(data)
# Out:
# bytes

# %%
with open("copy_image.jpg", "wb") as file:
    file.write(data)

# %%
from PIL import Image

image = Image.open('rohit and virat.jpg')
image.show()

# %%
from IPython.display import display, Image
display(Image(filename='rohit and virat.jpg'))
